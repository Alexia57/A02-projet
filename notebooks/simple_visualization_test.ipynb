# %% [markdown]
# # Visualisation simple
#
# ## Question 1

# %%
from simple_visualization import shot_type_analysis, calculate_distances_hockey, plot_goal_probability_by_distance, plot_goal_percentage
import pandas as pd

# %%
df = pd.read_csv("../nhl_all_years_clean.csv")

# On convertit la colonne "date" en objets datetime
df['dateTime'] = pd.to_datetime(df['dateTime'])

# Puis on ajoute une nouvelle colonne "annee" avec l'année
df['year'] = df['dateTime'].dt.year

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                  dateTime  period periodTime  \
# 0             0           0 2016-10-12 23:19:59+00:00       1      01:11
# 1             1           0 2016-10-12 23:21:41+00:00       1      02:53
# 2             2           0 2016-10-12 23:23:17+00:00       1      04:01
# 3             3           0 2016-10-12 23:24:02+00:00       1      04:46
# 4             4           0 2016-10-12 23:27:30+00:00       1      06:46
#
#   event eventTypeId  eventId  \
# 0  Shot        SHOT        8
# 1  Shot        SHOT       11
# 2  Shot        SHOT       15
# 3  Shot        SHOT       16
# 4  Shot        SHOT       24
#
#                                          description   typeDeTir strength  \
# 0  Mitchell Marner Wrist Shot saved by Craig Ande...  Wrist Shot      NaN
# 1  Chris Kelly Wrist Shot saved by Frederik Andersen  Wrist Shot      NaN
# 2    Cody Ceci Wrist Shot saved by Frederik Andersen  Wrist Shot      NaN
# ...

# %%
shot_type_analysis(df, years=[2018])
# Out:
# typeDeTir
# Backhand      0.11
# Slap Shot     0.06
# Snap Shot     0.10
# Wrist Shot    0.09
# dtype: float64

# %% [markdown]
# ## Question 2
